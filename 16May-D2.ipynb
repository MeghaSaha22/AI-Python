# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[1,4,9,16,25]
plt.plot(x,y,'r*')
plt.xlabel("x-values")
plt.ylabel("y-values")
plt.title("x-y dependency")
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[1,4,9,16,25]
plt.plot(x,y,'go')
plt.xlabel("x-values")
plt.ylabel("y-values")
plt.title("x-y dependency")
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[1,4,9,16,25]
plt.plot(x,y,'k*')
plt.plot(x,y)
plt.xlabel("x-values")
plt.ylabel("y-values")
plt.title("x-y dependency")
plt.show()

# %%
import matplotlib.pyplot as plt
names=["Rajesh","Jit","Kamal"]
marks=[88,69,99]
plt.bar(names,marks)
plt.xlabel("names")
plt.ylabel("marks")
plt.title("STUDENT PERFORMANCE")
plt.show()

# %%
import pandas as pd
df=pd.read_csv('Student.csv')
print(df)
# Out:
#    Roll      Name  Marks
# 0     1     Megha     99
# 1     2  Dhansiri     98
# 2     3     Priti     97
# 3     4    Pritha     96
# 4     5  Prakriti     95

# %%
import pandas as pd
plt.bar(df["Name"],df["Marks"])
plt.xlabel("Name")
plt.ylabel("Marks")

plt.show()

# %%
import matplotlib.pyplot as plt
goaltype=["Eating","Reading","Teaching"]
goals=[20,38,43]
colors=['y','r','b']
plt.pie(goals)
plt.show()

# %%
import matplotlib.pyplot as plt
goaltype=["Eating","Reading","Teaching"]
goals=[20,38,43]
colors=['y','r','b']
plt.pie(goals,labels=goaltype)
plt.show()

# %%
import matplotlib.pyplot as plt
goaltype=["Eating","Reading","Teaching"]
goals=[20,38,43]
colrs=['y','r','b']
plt.pie(goals,labels=goaltype,colors=colrs)
plt.show()

# %%
import matplotlib.pyplot as plt
goaltype=["Eating","Reading","Teaching"]
goals=[20,38,43]
colrs=['y','r','b']
plt.pie(goals,labels=goaltype,colors=colrs,autopct='%.2f%%')
plt.show()

# %%
import matplotlib.pyplot as plt
goaltype=["Eating","Reading","Teaching"]
goals=[20,38,43]
colrs=['y','r','b']
plt.pie(goals,labels=goaltype,colors=colrs,autopct='%.2f%%',explode=(0.1,0.1,0.1))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(-10,9,20)
y=x**3
plt.subplot(2,2,1)
plt.plot(x,y,'b*-')
plt.subplot(2,2,2)
plt.plot(x,y,'gp-')
plt.subplot(2,2,3)
plt.plot(x,y,'yo-')
plt.subplot(2,2,4)
plt.plot(x,y,'r^-')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(-1,10,30)
y=np.sin(x)
plt.plot(x,y,'p-',color='violet')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(-1,10,30)
y=np.sin(x)
plt.plot(x,y,'*-',color='violet',markersize=15,linewidth=3)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(-1,10,30)
y=np.sin(x)
plt.plot(x,y,'*-',color='violet',markersize=15,linewidth=3,markerfacecolor='red',markeredgecolor='purple',markeredgewidth=3
        )
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
rng=np.random.RandomState(42)
x=rng.randn(100)
y=rng.randn(100)
colrs=rng.randn(100)
sizes=1000*rng.randn(100)
plt.scatter(x,y,c=colrs,s=sizes,alpha=.9,cmap='autumn')
plt.colorbar()
plt.show()

# %%
import pandas as pd
df=pd.read_csv("Salary_Data.csv")
x=df.iloc[:,0:1].values
y=df.iloc[:,1].values
from sklearn.model.selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=3,random_state=1)
from sklearn.linear_model import LinearRegression
rg=LinearRegression()
rg.fit(x_train,y_train)
y_pred=rq.predict(x_test)
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test,y_pred)
import numpy as np
rmse=np
print("Error=",rmse)
m=rg.coef
c=rg.intercept
s1=m*2.3+c
print("salary=",S1)
s2=rq.predict([[2.3]])
print("Now=",S2)

# %%
import pandas as pd
df=pd.read_csv("Salary_Data.csv")
x=df.iloc[:,0:1].values
y=df.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=3,random_state=1)
from sklearn.linear_model import LinearRegression
rg=LinearRegression()
rg.fit(x_train,y_train)
y_pred=rg.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test,y_pred)

# %%
import numpy as np
rmse=np.sqrt(mse)
print("Error=",rmse)
# Out:
# Error= 5733.525639176546

# %%
m=rg.coef_
c=rg.intercept_
s1=m*2.3+c
print("Salary=",s1)
s2=rg.predict([[2.3]])
print("Now=",s2)
# Out:
# Salary= [47149.64134602]
# Now= [47149.64134602]

# %%
import matplotlib.pyplot as plt
plt.plot(x_train,y_train,'r*')
p=rg.predict(x_train)
plt.plot(x_train,p)
plt.xlabel("exp")
plt.ylabel("salary")
plt.show()

# %%
import turtle as t
pen = t.Turtle()
t.bgcolor('#000000')
t.delay(8)
pen.color('#ff0000')
pen.begin_fill()
pen.left(40)
pen.forward(120)
pen.circle(80, 190)
pen.right(100)
pen.circle(80, 180)
pen.forward(160)
pen.left(90)
pen.forward(50)
#pen.setpos(-60, 100)
pen.end_fill()
def txt():
    pen.up()
    pen.setpos(-60, 100)
    pen.color('black')
    pen.write('I Love YOU', font=("Times New Roman", 16))
txt()
pen.end_fill()
t.exitonclick()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20676\1222178427.py in <module>
#       1 import turtle as t
# ----> 2 pen = t.Turtle()
#       3 t.bgcolor('#000000')
#       4 t.delay(8)
#       5 pen.color('#ff0000')
#
# ~\anaconda3\lib\turtle.py in __init__(self, shape, undobuffersize, visible)
#    3813         if Turtle._screen is None:
#    3814             Turtle._screen = Screen()
# -> 3815         RawTurtle.__init__(self, Turtle._screen,
#    3816                            shape=shape,
#    3817                            undobuffersize=undobuffersize,
#
# ~\anaconda3\lib\turtle.py in __init__(self, canvas, shape, undobuffersize, visible)
#    2556         self._undobuffersize = undobuffersize
#    2557         self.undobuffer = Tbuffer(undobuffersize)
# -> 2558         self._update()
#    2559
#    2560     def reset(self):
#
# ...
